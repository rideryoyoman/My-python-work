# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import json

# %%
f = open('PeriodicTableJSON.json')

# %%
egg = json.load(f)

# %%
f.close()

# %%
df = pd.DataFrame(egg['elements'])

# %%
df
# Out:
#                                             appearance  atomic_mass  \
# 0                                        metallic gray   207.210000
# 1                                        silvery white   204.380000
# 2                                        silvery white   174.966810
# 3                                         silvery gray   168.934222
# 4                                        silvery white   243.000000
# 5                                                 None   293.000000
# 6                                        silvery white   150.362000
# 7                                                 None   289.000000
# 8                                        silvery white   106.421000
# 9                                pale yellow-green gas    35.450000
# 10   colourless, waxy white, yellow, scarlet, red, ...    30.973762
# 11                                     lustrous silver   208.980401
# 12   colorless gas, occasionally glows green or red...   222.000000
# ...

# %%
df_sorted = df.sort_values(by=["ypos","xpos"], ascending=True)

# %%
df_sorted
# Out:
#                                             appearance  atomic_mass  \
# 116                                      colorless gas     1.008000
# 50   colorless gas, exhibiting a red-orange glow wh...     4.002602
# 97                                       silvery-white     6.940000
# 61                                 white-gray metallic     9.012183
# 104                                        black-brown    10.810000
# 69                                                None    12.011000
# 23                      colorless gas, liquid or solid    14.007000
# 30                                                None    15.999000
# 87                                                None    18.998403
# 20   colorless gas exhibiting an orange-red glow wh...    20.179760
# 25                              silvery white metallic    22.989769
# 14                                    shiny grey solid    24.305000
# 18                               silvery gray metallic    26.981539
# ...

# %%
df.ypos.plot()

# %%
df_sorted.ypos.plot()

# %%
df_sorted.index = range(1, 119)

# %%
df_sorted
# Out:
#                                             appearance  atomic_mass  \
# 1                                        colorless gas     1.008000
# 2    colorless gas, exhibiting a red-orange glow wh...     4.002602
# 3                                        silvery-white     6.940000
# 4                                  white-gray metallic     9.012183
# 5                                          black-brown    10.810000
# 6                                                 None    12.011000
# 7                       colorless gas, liquid or solid    14.007000
# 8                                                 None    15.999000
# 9                                                 None    18.998403
# 10   colorless gas exhibiting an orange-red glow wh...    20.179760
# 11                              silvery white metallic    22.989769
# 12                                    shiny grey solid    24.305000
# 13                               silvery gray metallic    26.981539
# ...

# %%
df_sorted.xpos.plot()

# %%
df_sorted["number"].mean()
# Out:
# 1.0462439754331537e+243

# %%
df_sorted.atomic_mass.plot()

# %%
df_1A = df_sorted[df_sorted.xpos==1]

# %%
df_sorted.density.plot()
