# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pi
# Out:
# 3.141592653589793

# %%
plot([-2,10,3,13,8])

# %%
plot([1,3.7,5,8.8],[12,5,3.5,8])

# %% [markdown]
# 自由作筆記ㄌ!

# %% [markdown]
# #大標
# ##中標
# ###小標
# 拍桑

# %% [markdown]
# # 大標

# %% [markdown]
# # 作筆記囉
# *做一個連結
#
# [sprint](https://www.facebook.com/HackSprint/)

# %%
![me](yoyoman.jpg)
# Out:
# '[me]' 不是內部或外部命令、可執行的程式或批次檔。

# %% [markdown]
# ![me](yoyoman.jpg)

# %% [markdown]
# #[名字](連結/圖片名字)可以製造超連結或圖片

# %% [markdown]
# #中括號裡面放名字，小括號裡面放連結或圖片 可以製造超連結或是圖片

# %% [markdown]
# # Random normal

# %%
randn(5)
# Out:
# array([ 0.23155549, -0.27462802,  1.87603886, -0.97495705,  1.6954098 ])

# %%
plot(randn(3))

# %% [markdown]
# # random integer

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
randint(3 , 21)
# Out:
# 3

# %%
for i in range(10):
    k = randint(1,100)
    print(" "* k + "*")
# Out:
#                                                    *
#                                                           *
#                                                  *
#                                                                              *
#                                                                             *
#                                                         *
#                  *
#                       *
#            *
#                                 *

# %%
from numpy import sin

# %%
sin(3)
# Out:
# 0.1411200080598672

# %%
pi
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-f84ab820532c> in <module>()
# ----> 1 pi
#
# NameError: name 'pi' is not defined

# %%
from numpy import *

# %%
pi
# Out:
# 3.141592653589793

# %%
randint (1,10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-fad96fc7ed44> in <module>()
# ----> 1 randint (1,10)
#
# NameError: name 'randint' is not defined

# %%
from random import *

# %%
randint(1,10)
# Out:
# 6

# %%
for i in range(50):
    print(randint(1,10),end=", ")
# Out:
# 10, 4, 9, 3, 5, 5, 6, 4, 4, 1, 3, 5, 7, 9, 6, 1, 8, 6, 3, 9, 9, 7, 3, 6, 1, 7, 9, 9, 2, 5, 10, 2, 1, 5, 9, 7, 2, 7, 9, 3, 1, 10, 1, 7, 6, 3, 1, 8, 9, 9,

# %%
from numpy.random import *

# %%
for i in range(50):
    print(randint(1,10), end = ", ")
# Out:
# 7, 1, 2, 6, 6, 2, 7, 5, 4, 5, 1, 6, 3, 9, 8, 2, 4, 7, 1, 7, 2, 6, 3, 7, 7, 1, 1, 8, 4, 1, 7, 3, 1, 7, 4, 9, 2, 4, 2, 5, 9, 8, 3, 7, 2, 7, 5, 8, 8, 2,

# %% [markdown]
# # import * 可能造成很多地方出錯

# %%
import numpy

# %%
numpy.pi
# Out:
# 3.141592653589793

# %% [markdown]
# # import 套件 as 套件綽號

# %%
import numpy as np

# %%
np.pi
# Out:
# 3.141592653589793

# %% [markdown]
# ## 數據分析的標準動作

# %%
# %matplotlib inline

# %% [markdown]
# 以後有畫圖的話 直接把圖呈現在網頁上

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
np.pi
# Out:
# 3.141592653589793

# %%
plt.plot([3,5,8,13])

# %%
plt.plot(np.random.randn(100))
