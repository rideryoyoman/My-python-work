# %%
import requests
import re
from pyquery import PyQuery as pq
from bs4 import BeautifulSoup as bs

Dic = {"麥當勞":"20" , "肯德基":"21" , "摩斯漢堡":"22" 
      , "subway":"23" , "爭鮮":"24" , "cold stone":"25"
      , "必勝客":"26" , "達美樂":"27" , "拿坡里":"28"
      , "王品":"29" , "西堤":"30" , "陶板屋":"31"
      , "85度C":"32" , "星巴克":"33" , "伯朗咖啡":"34"
      , "怡客咖啡":"35" , "丹堤咖啡":"36" , "8％ice":"37"
      , "21世紀":"38" , "吉野家":"39" , "Mister Donut":"40"
      , "藝奇":"41" , "夏慕尼":"42" , "聚北海道":"43"
      , "FRIDAYS":"44" , "三商巧福":"45" , "福勝亭":"46"
      , "漢堡王":"47" , "頂呱呱":"48" , "原燒":"49"
       , "711":"1" , "全家":"2"
      , "萊爾富":"3" , "OK":"4" , "全聯":"5"
      , "家樂福":"6" , "愛買":"7" , "康是美":"8"
      , "大潤發":"9" , "HOLA":"10" , "特力屋":"11"
      , "屈臣氏":"12" , "劍湖山":"13" , "六福村":"14"
      , "義大":"15" , "好市多":"16" , "九族文化村":"17"
      , "小人國":"18" , "頂好":"19" 
      ,"義美":"50" , "悠遊卡":"51" , "一卡通":"52"
      ,"美廉社":"55" , "寶雅":"56" , "小北百貨":"58"
      }

number = Dic[input("今天你想吃什麼><")]
url = "http://coupon.baibai.com.tw/Coupon.asp?store=" + number

res = requests.get(url)
res.encoding = "big5"
doc = pq(res.text)
soup = bs(res.text, 'html.parser')
#ans = soup.find('a',href = "Coupon.asp?store=" + number)
#ans = soup.find_all('img')
for link in soup.find_all('a'):
    ans = link.get('href')
    if "jpg" in ans:
        print(ans)
        print("----------------------")
a = input()
# Out:
# 今天你想吃什麼><711
# http://www.7-11.com.tw/2week/180523/2018/KIRIN.jpg
# ----------------------
# http://www.7-11.com.tw/2week/180523/2018/0523OP.jpg
# ----------------------
# http://www.7-11.com.tw/2week/180509/2018/beer.jpg
# ----------------------
# http://www.7-11.com.tw/2week/180425/2018/can.jpg
# ----------------------
# http://www.7-11.com.tw/2week/180606/2018/fruit.jpg
# ----------------------
# http://www.7-11.com.tw/2week/180523/2018/health.jpg
# ----------------------
# http://www.7-11.com.tw/2week/180523/2018/heineken.jpg
# ----------------------
# http://www.7-11.com.tw/2week/180523/2018/beer.jpg
# ----------------------
# http://www.7-11.com.tw/2week/180523/2018/exercising.jpg
# ----------------------
# http://www.7-11.com.tw/2week/180523/2018/b1g1f.jpg
# ----------------------
# http://www.7-11.com.tw/2week/180606/2018/breakfast.jpg
# ----------------------
# http://www.7-11.com.tw/2week/180509/2018/lemon.jpg
# ----------------------
# http://www.7-11.com.tw/2week/180523/2018/ab.jpg
# ----------------------
# http://www.7-11.com.tw/2week/180606/2018/black.jpg
# ----------------------
# http://www.7-11.com.tw/2week/180606/2018/drink.jpg
# ----------------------
# http://www.7-11.com.tw/2week/180523/2018/food.jpg
# ----------------------
# http://www.7-11.com.tw/2week/180606/2018/love.jpg
# ----------------------
# http://www.7-11.com.tw/2week/180606/2018/fifa.jpg
# ----------------------
# http://www.7-11.com.tw/2week/180606/2018/vintage.jpg
# ----------------------
# http://www.7-11.com.tw/2week/180606/2018/oden.jpg
# ----------------------
# http://www.7-11.com.tw/2week/180606/2018/ka.jpg
# ----------------------
# http://www.7-11.com.tw/2week/180606/2018/summer.jpg
# ----------------------
# http://www.7-11.com.tw/2week/180606/2018/cloth.jpg
# ----------------------
# http://www.7-11.com.tw/2week/180606/2018/lottery.jpg
# ----------------------

# %%
k = soup.find_all()
