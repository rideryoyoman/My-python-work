# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
x
# Out:
# array([0.        , 0.10204082, 0.20408163, 0.30612245, 0.40816327,
#        0.51020408, 0.6122449 , 0.71428571, 0.81632653, 0.91836735,
#        1.02040816, 1.12244898, 1.2244898 , 1.32653061, 1.42857143,
#        1.53061224, 1.63265306, 1.73469388, 1.83673469, 1.93877551,
#        2.04081633, 2.14285714, 2.24489796, 2.34693878, 2.44897959,
#        2.55102041, 2.65306122, 2.75510204, 2.85714286, 2.95918367,
#        3.06122449, 3.16326531, 3.26530612, 3.36734694, 3.46938776,
#        3.57142857, 3.67346939, 3.7755102 , 3.87755102, 3.97959184,
#        4.08163265, 4.18367347, 4.28571429, 4.3877551 , 4.48979592,
#        4.59183673, 4.69387755, 4.79591837, 4.89795918, 5.        ])

# %%
y = 1.2 * x + 0.8

# %%
plt.scatter(x,y)
plt.plot(x,y,'r')

# %%
y = 1.2 * x + 0.8 + 0.6 * np.random.randn(50)

# %%
y
# Out:
# array([1.50158369, 0.67007559, 1.14520871, 1.96646994, 1.24532752,
#        0.39431895, 0.85226112, 1.26196637, 0.92434891, 1.47480535,
#        1.91866293, 1.59744571, 2.35676591, 1.78324782, 2.80064113,
#        3.44393885, 2.9860565 , 2.56551368, 3.52399494, 2.79590209,
#        2.18297077, 4.29935957, 3.21818694, 2.99022238, 2.74464732,
#        5.59408984, 4.13422136, 4.50111932, 3.95698235, 2.92221559,
#        4.91941856, 4.13613034, 4.81372972, 4.87635223, 5.86221322,
#        5.506686  , 5.97678894, 6.32572321, 4.40069866, 5.38460142,
#        4.89076607, 5.72984464, 6.33196578, 6.14071937, 4.91081923,
#        5.64900898, 6.83068224, 7.20820258, 6.7663967 , 6.34426357])

# %%
plt.scatter(x,y)
plt.plot(x,1.2 * x + 0.8,'r')
